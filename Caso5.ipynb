# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoAlejandroSoto/phytonCasos/blob/main/Caso5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Objetivo
#
# Realizar una prueba de normalidad de dos conjuntos de datos mediante una prueba de cuartiles.
#
# Estos son los primeros datos:
#
# 73, 74, 94, 81, 71, 79, 86, 92, 82, 70, 72, 70, 72, 77, 84, 71, 73, 78, 78, 89, 84, 85, 73, 78, 63, 84, 78, 84, 76, 71, 88, 76, 83, 74, 76, 79, 78, 79, 71, 66, 85, 89, 88, 71, 80, 68, 93, 83, 93, 98, 84, 83, 96, 89, 73, 90, 86, 84, 89, 88, 66, 92, 70, 84, 79, 68, 89, 90, 83, 71, 73, 96, 84, 78, 78, 80, 78, 66, 73, 85, 84, 85, 67, 83, 77, 86, 69, 84, 69, 79, 83, 79, 81, 75, 73, 92, 87, 71, 83, 76, 82, 82, 84, 66, 78, 94, 82, 58, 72, 83, 73, 95, 84, 84, 83, 85, 78, 77, 78, 85

# %% [markdown]
# # Desarrollo

# %% [markdown]
# ## Cargar librerías

# %%
import numpy as np
import statsmodels.api as sm
import pylab

# %% [markdown]
# ## Crear los datos

# %%
datos = [73, 74, 94, 81, 71, 79, 86, 92, 82, 70, 72, 70, 72, 77, 84, 71, 73, 78, 78, 89, 84, 85, 73, 78, 63, 84, 78, 84, 76, 71, 88, 76, 83, 74, 76, 79, 78, 79, 71, 66, 85, 89, 88, 71, 80, 68, 93, 83, 93, 98, 84, 83, 96, 89, 73, 90, 86, 84, 89, 88, 66, 92, 70, 84, 79, 68, 89, 90, 83, 71, 73, 96, 84, 78, 78, 80, 78, 66, 73, 85, 84, 85, 67, 83, 77, 86, 69, 84, 69, 79, 83, 79, 81, 75, 73, 92, 87, 71, 83, 76, 82, 82, 84, 66, 78, 94, 82, 58, 72, 83, 73, 95, 84, 84, 83, 85, 78, 77, 78, 85]
print ("Los datos")
print(datos)
# Out:
# Los datos
# [73, 74, 94, 81, 71, 79, 86, 92, 82, 70, 72, 70, 72, 77, 84, 71, 73, 78, 78, 89, 84, 85, 73, 78, 63, 84, 78, 84, 76, 71, 88, 76, 83, 74, 76, 79, 78, 79, 71, 66, 85, 89, 88, 71, 80, 68, 93, 83, 93, 98, 84, 83, 96, 89, 73, 90, 86, 84, 89, 88, 66, 92, 70, 84, 79, 68, 89, 90, 83, 71, 73, 96, 84, 78, 78, 80, 78, 66, 73, 85, 84, 85, 67, 83, 77, 86, 69, 84, 69, 79, 83, 79, 81, 75, 73, 92, 87, 71, 83, 76, 82, 82, 84, 66, 78, 94, 82, 58, 72, 83, 73, 95, 84, 84, 83, 85, 78, 77, 78, 85]

# %% [markdown]
# ## Construir el gráfico de qqplot
#
# El gráfico de comparación de cuantiles, también llamado, *qqplot*, representa los cuantiles de los datos comaprado contra los cuantiles teóricos que tendría si siguiese una distribución normal con una media y desviación estándar igual.
#
# Si los datos siguen una distribución normal, se alinearán cerca de la diagonal del gráfico. Cuanto más se alejen, menos probable será que nuestros datos sigan una distribución normal.

# %%
# Crear el QQ-Plot
sm.qqplot(np.array(datos), line='q')

# Configurar el gráfico
plt.title('QQ-Plot')
plt.xlabel('Cuantiles teóricos de la distribución normal')
plt.ylabel('Cuantiles de los datos')

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7238ec9acce1> in <cell line: 5>()
#       3
#       4 # Configurar el gráfico
# ----> 5 plt.title('QQ-Plot')
#       6 plt.xlabel('Cuantiles teóricos de la distribución normal')
#       7 plt.ylabel('Cuantiles de los datos')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Dicen que una imagen vale más que mil palabras, ¿están los datos alineados a una linea roja?
#
# No se observa una alineación consistente con la línea roja que representa la distribución normal teórica simulada a partir de los mismos valores estadístcos de media y desviación estándar.
#
# Los datos no provienen de una distribución normal
#
# Esta prueba enriquece, fortalece y corrobora las pruebas de *Kolmogorov Smirnov* y *Shapiro Wilk*.

# %% [markdown]
# ## Gráfico qqplot de calificaciones
#
# Con los datos de calificaiones se hace la prueba qqplot.

# %% [markdown]
# ## Datos de calificaciones
#
# 85.21, 89.22, 82.37, 92.38, 84.7, 86.06, 79.42, 87.83, 88.05, 86.47, 82.69, 83.34, 84.45, 90.18, 87.08, 84.22, 83.46, 72.74, 82.33, 85.23, 81.36, 79.05, 89.68, 86.57, 87.12, 82.65, 89.23, 82.06, 84.66, 85.51, 86.38, 87.74, 86.6, 88.57, 86.54, 87.56, 82.69, 81.72, 87.99, 92.35

# %%
calificaciones = [85.21, 89.22, 82.37, 92.38, 84.7, 86.06, 79.42, 87.83, 88.05, 86.47, 82.69, 83.34, 84.45, 90.18, 87.08, 84.22, 83.46, 72.74, 82.33, 85.23, 81.36, 79.05, 89.68, 86.57, 87.12, 82.65, 89.23, 82.06, 84.66, 85.51, 86.38, 87.74, 86.6, 88.57, 86.54, 87.56, 82.69, 81.72, 87.99, 92.35]

print ("Calificaciones de alumnos")
print(calificaciones)
# Out:
# Calificaciones de alumnos
# [85.21, 89.22, 82.37, 92.38, 84.7, 86.06, 79.42, 87.83, 88.05, 86.47, 82.69, 83.34, 84.45, 90.18, 87.08, 84.22, 83.46, 72.74, 82.33, 85.23, 81.36, 79.05, 89.68, 86.57, 87.12, 82.65, 89.23, 82.06, 84.66, 85.51, 86.38, 87.74, 86.6, 88.57, 86.54, 87.56, 82.69, 81.72, 87.99, 92.35]

# %%
sm.qqplot(np.array(calificaciones), line='q')

# Configurar el gráfico
plt.title('QQ-Plot')
plt.xlabel('Cuantiles teóricos de la distribución normal')
plt.ylabel('Cuantiles de las calificaciones')

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-65ee8dae890b> in <cell line: 4>()
#       2
#       3 # Configurar el gráfico
# ----> 4 plt.title('QQ-Plot')
#       5 plt.xlabel('Cuantiles teóricos de la distribución normal')
#       6 plt.ylabel('Cuantiles de las calificaciones')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Se observa que los datos de calificaciones si están alineados a la línea roja por lo que se presume que son datos que si tienen un comportamiento normal o que si provienen de una distribución normal.

# %% [markdown]
# # Interpretación
#
# ¿Los datos pasan la prueba de normalidad de acuerdo al método de prueba de caurtiles qqplot?
# SI
#
# Describir lo que les deja el caso comaprado con los casos 03 y caso 04.
# La verdad no encontre alguna comparacion valida para diferenciar los casos , los procesos fueron un poco diferentes pero fue lo unico que note
